# %% [markdown]
# <a href="https://colab.research.google.com/github/rizalpangestu1/Machine-Learning/blob/main/ML_GymLens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install scikit-learn

# %%
import os
import random
import numpy as np
from io import BytesIO

# Plotting and dealing with images
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf

# %%
BASE_DIR = 'Gym Equipment'

train_benchpress_dir = os.path.join(BASE_DIR, 'Bench Press')
train_dumbells_dir = os.path.join(BASE_DIR, 'Dumbells')
train_ellipticalmachine_dir = os.path.join(BASE_DIR, 'Elliptical Machine')
train_recumbentbike_dir = os.path.join(BASE_DIR, 'Recumbent Bike')
train_smithmachine_dir = os.path.join(BASE_DIR, 'Smith Machine')
